# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
firstData=pd.read_csv("first.csv")

# %%
firstData.head()
# Out:
#                       98; (610)057-2703x68335; Lloyd  \
# 0     167; 388.428.1133x155; Ward LLC; Donald; Smith
# 1  12; (692)863-8994x075; Mendoza Inc; Jonathan; ...
# 2  31; (998)028-4972x3923; Hayden Group; Tracy; D...
# 3  186; 387.507.2514; Braun-Hoffman; Jeff; Nicholson
# 4   192; 161.456.4446x4724; Harris-Hurst; Debra; Gay
#
#    Turner and Ware; John; Robertson
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN

# %%
firstData1=pd.read_csv("first.csv",sep=";")

# %%
firstData1.head()
# Out:
#     98  (610)057-2703x68335  Lloyd, Turner and Ware       John   Robertson
# 0  167     388.428.1133x155                Ward LLC     Donald       Smith
# 1   12    (692)863-8994x075             Mendoza Inc   Jonathan   Rodriguez
# 2   31   (998)028-4972x3923            Hayden Group      Tracy      Dillon
# 3  186         387.507.2514           Braun-Hoffman       Jeff   Nicholson
# 4  192    161.456.4446x4724            Harris-Hurst      Debra         Gay

# %%
names=['id','phone','company','firstname','lastname']

# %%
df=pd.read_csv("first.csv",sep=";",names=names,index_col="id")

# %%
df.head()
# Out:
#                     phone                  company  firstname    lastname
# id
# 98    (610)057-2703x68335   Lloyd, Turner and Ware       John   Robertson
# 167      388.428.1133x155                 Ward LLC     Donald       Smith
# 12      (692)863-8994x075              Mendoza Inc   Jonathan   Rodriguez
# 31     (998)028-4972x3923             Hayden Group      Tracy      Dillon
# 186          387.507.2514            Braun-Hoffman       Jeff   Nicholson

# %%
df.columns
# Out:
# Index(['phone', 'company', 'firstname', 'lastname'], dtype='object')

# %%
df.sort_values(by=['id'])
# Out:
#                        phone                        company   firstname  \
# id
# 1           690-334-2003x565         Lane, Short and Martin     Melissa
# 2               825-306-5686                    Heath Group     Cynthia
# 3     001-106-038-9008x24855                     Ellis-Wise       Emily
# 4     001-147-207-7805x82814                  Robertson PLC   Stephanie
# 5       001-103-784-3362x235                     Graves PLC   Christina
# 6              (488)961-8260     Wade, Butler and Stevenson      Curtis
# 7          (888)193-4255x490                Barnes and Sons       James
# 8     001-269-596-5780x20662        White, Cochran and Bush     Mallory
# 9          (318)687-2446x736                 Vaughn-Ramirez   Christine
# 10      001-782-355-7584x555    Hernandez, Thomas and Baird       Kelly
# 11                1365985048          Porter, Rose and Diaz        Rick
# 12         (692)863-8994x075                    Mendoza Inc    Jonathan
# ...
